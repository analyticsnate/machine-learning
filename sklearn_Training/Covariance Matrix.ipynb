# %% [markdown]
# ### Covariance matrix
# figure out which features are strongly related and which aren't

# %%
from sklearn import datasets
import numpy as np

# %%
iris = datasets.load_iris()

# %%
# numpy.corrcoef creates a Pearson product-moment correlation matrix
# very cool!
cov_data = np.corrcoef(iris.data.T)

# %%
print(iris.feature_names)
print(cov_data)
# Out:
# ['sepal length (cm)', 'sepal width (cm)', 'petal length (cm)', 'petal width (cm)']
# [[ 1.         -0.10936925  0.87175416  0.81795363]
#  [-0.10936925  1.         -0.4205161  -0.35654409]
#  [ 0.87175416 -0.4205161   1.          0.9627571 ]
#  [ 0.81795363 -0.35654409  0.9627571   1.        ]]

# %%
import matplotlib.pyplot as plt
img = plt.matshow(cov_data, cmap=plt.cm.rainbow)
plt.colorbar(img, ticks=[-1, 0, 1], fraction=0.045)

for x in range(cov_data.shape[0]):
    for y in range(cov_data.shape[1]):
        plt.text(x, y, "%0.2f" % cov_data[x,y], size=12, color='black'
                , ha='center', va='center')

plt.show()

# %%
def cov_matrix_plot(data):
    cov_data = np.corrcoef(data)
    img = plt.matshow(cov_data, cmap=plt.cm.rainbow)
    plt.colorbar(img, ticks=[-1, 0, 1], fraction=0.045)

    #for x in range(cov_data.shape[0]):
    #    for y in range(cov_data.shape[1]):
            #plt.text(x, y, "%0.2f" % cov_data[x,y], size=12, color='black'
            #        , ha='center', va='center')

    plt.show()

# %%
boston = datasets.load_boston()

# %%
cov_matrix_plot(boston.data.T)

# %%
diabeetus = datasets.load_diabetes()

# %%
cov_matrix_plot(diabeetus.data.T)
